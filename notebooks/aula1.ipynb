# %% [markdown]
# # Aula 1

# %% [markdown]
# Entender a inteligência artificial, além das ferramentas tem suas vantagens:
#
# - Você pode aprender a criar suas próprias soluções
# - Criar startups e empresas inovadoras
# - Pode apresentar as soluções prontas com autoridade
# - Pode utilizar-se de modelos pré-treinados
# - Preparar o currículo para novos empregos e oportunidades
# - Se atualizar de novos recursos tecnológicos

# %%
import pandas as pd
import matplotlib
df = pd.read_csv('../datasets/flor.csv')


'''url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'
df = pd.read_csv(url)
'''
# Out:
# "url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'\ndf = pd.read_csv(url)\n"

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df = df.rename(columns={'sepal.length': 'sépala_compimento', 'sepal.width': 'sépala_largura','petal.length': 'pétala_compimento', 'petal.width': 'pétala_largura','variety': 'Variedade'})

'''
#Trocar todos os . por _
df.columns=[s.replace('.','_') for s in df.columns]
'''
# Out:
# "\n#Trocar todos os . por _\ndf.columns=[s.replace('.','_') for s in df.columns]\n"

# %%
df['Variedade'].value_counts()
# Out:
# Variedade
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#    sépala_compimento  sépala_largura  pétala_compimento  pétala_largura  \
# 0                5.1             3.5                1.4             0.2
# 1                4.9             3.0                1.4             0.2
# 2                4.7             3.2                1.3             0.2
# 3                4.6             3.1                1.5             0.2
# 4                5.0             3.6                1.4             0.2
#
#   Variedade
# 0    Setosa
# 1    Setosa
# 2    Setosa
# 3    Setosa
# 4    Setosa

# %%
df_setosa= df.query('Variedade == "Setosa"').copy()
df_virginica= df.query('Variedade == "Virginica"').copy()
df_versicolor= df.query('Variedade == "Versicolor"').copy()

# %%
medidas = ['sépala_compimento','sépala_largura','pétala_compimento','pétala_largura']

# %%
df_setosa[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sépala_compimento'}>,
#         <Axes: title={'center': 'sépala_largura'}>],
#        [<Axes: title={'center': 'pétala_compimento'}>,
#         <Axes: title={'center': 'pétala_largura'}>]], dtype=object)

# %%
df_versicolor[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sépala_compimento'}>,
#         <Axes: title={'center': 'sépala_largura'}>],
#        [<Axes: title={'center': 'pétala_compimento'}>,
#         <Axes: title={'center': 'pétala_largura'}>]], dtype=object)

# %%
df_virginica[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sépala_compimento'}>,
#         <Axes: title={'center': 'sépala_largura'}>],
#        [<Axes: title={'center': 'pétala_compimento'}>,
#         <Axes: title={'center': 'pétala_largura'}>]], dtype=object)

# %% [markdown]
# # Inteligência Artificial
# - Máquinas que imitam comportamentos humanos (Seres vivos)
# - Esse conceito é geral (guarda-chuva)
# - Máquinas e softwares que tomam decisões e podem o prever o futuro.
# - Máquinas inteligentes que podem executar desde tarefas simples de automação até vencer um humano em uma partida de xadres
#
# ###### Kung-Fusão

# %% [markdown]
# - mochine Learning
# - Área dentro da IA
# - Pode ser visto como uma área dentro da inteligência artificial e se refere a técnicas para construir conhecimento (estimar funções) a partir de observações (0,1) - variáveis explicativas, variável target (alvo)
